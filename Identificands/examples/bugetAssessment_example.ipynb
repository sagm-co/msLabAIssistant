# %%
import sys,time,os
import pandas as pd
import numpy as np
pd.set_option('future.no_silent_downcasting', True)
sys.path.append(os.environ['IDENTIFICANDS_BASEPATH'])
from Identificands import Identificands
iidentificands=Identificands()

# %%
iidentificands.analysisFrameworks
# Out:
#                         Analysis frameworks
# targeted-analysis                     False
# suspect-screening                     False
# non-targeted-screening                False

# %%
iidentificands.resultsPath="./resultsData/"
iidentificands.rawFile="./raw/Sample4_Papaya.raw"

# %%
identificandsData=iidentificands.getIdentificandsNaiveProbabilityCombination()
display(identificandsData)
# Out:
#      CompNum                                    canonicalSmiles  \
# 0          1   CON=C(C(=O)OC)c1ccccc1CON=C(C)c1cccc(C(F)(F)F)c1
# 1          2      COC=C(C(=O)OC)c1ccccc1Oc1cc(Oc2ccccc2C#N)ncn1
# 2          3            CCCN(CCOc1c(Cl)cc(Cl)cc1Cl)C(=O)n1ccnc1
# 3          4                 O=[N+]([O-])N=C1NCCN1Cc1ccc(Cl)nc1
# 4          5               CC(C)(C)C(O)(CCc1ccc(Cl)cc1)Cn1cncn1
# ..       ...                                                ...
# 692       96                                C=CCc1ccc2c(c1)OCO2
# 693       97         CCCn1c(=O)c2[nH]c(C3(N)CCCC3)nc2n(CCC)c1=O
# 694       98                             CC(=O)Oc1ccc2c(c1)OCO2
# 695       99  CC(=O)OCC(OC(C)=O)=C1C(C)CC2C3CCC4=CC(=O)C=CC4...
# 696      100                   CCCCCCCCCCCCOC(=O)CCCCCCCCC(=O)O
#
#                         inchikey  \
# 0    ONCZDRURRATYFI-UHFFFAOYSA-N
# 1    WFDXOXNFNRHQEC-UHFFFAOYSA-N
# 2    TVLSRXXIMLFWEO-UHFFFAOYSA-N
# 3    YWTYJOPNNQFBPC-UHFFFAOYSA-N
# ...

# %%
iidentificands.getIdentificandsBestNaiveProbability(88)
# Out:
#     CompNum                           canonicalSmiles  \
# 94       88  CC1C(=O)NCCCN1C(=O)CC(N)Cc1cc(F)c(F)cc1F
#
#                        inchikey  \
# 94  SWKGZJAAGSVROJ-UHFFFAOYSA-N
#
#                                                  name  bmonoisotopicMass  \
# 94  4-[3-Amino-4-(2,4,5-trifluorophenyl)butanoyl]-...         343.150761
#
#     identificationApproach   intensity       tR p_candidate candidatesNum  \
# 94  non-targeted-screening  54266824.0  9.38265           -             1
#
#     ... Effect_p_area_amenability Effect_p_area_tR_inference  \
# 94  ...                 15.377823                   22.09487
#
#    Effect_p_area_ionizedSpecies Effect_p_area_ms2  \
# 94                     1.751509         19.484977
#
#     Contribution_p_area_chromSignalQlty Contribution_p_area_isotopicProfile  \
# 94                             3.136478                            4.229081
#
#     Contribution_p_area_amenability  Contribution_p_area_tR_inference  \
# ...

# %%
iidentificands.plotProbabilityBudgets(88,assessType="Effect",areBest=False,withoufFiltering=True)

# %%
iidentificands.plotProbabilityBudgets(88,assessType="Components",areBest=False,withoufFiltering=True)

# %%
iidentificands.plotProbabilityBudgets(88,assessType="Contribution",areBest=False,withoufFiltering=True)

# %%
iidentificands.plotProbabilityBudgets(14,assessType="Effect",areBest=True)
