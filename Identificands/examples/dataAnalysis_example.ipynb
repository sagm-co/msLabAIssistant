# %% [markdown]
# ## **Identification Example Using *Identificands***

# %%
import sys,os
sys.path.append(os.environ['IDENTIFICANDS_BASEPATH'])
from Identificands import Identificands
iidentificands=Identificands()

# %%
iidentificands.intensityThreshold=2E4

# %%
iidentificands.resultsPath="./resultsData/"
iidentificands.filesToProcess="./inputData/samplesToProcess_MultiApproach.tsv"
iidentificands.analysisFrameworks

# %%
iidentificands.identifyMultipleFiles()
